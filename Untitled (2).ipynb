# %%
import pandas as pd
import scipy.stats as sci
from scipy import stats
from scipy.stats import ttest_ind
from scipy.stats import describe
#import all necessary lybraries
import sqlite3
import pymysql.cursors
import pandas as pd
import scipy.stats as sci
from sklearn.linear_model import LinearRegression
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import describe
from sklearn.cluster import KMeans
from pandas import DataFrame

# %%
df= pd.read_csv('bank_marketing.csv')

# %%
df.head()
# Out:
#     age           job  marital  education default  balance housing loan  \
# 0  58.0    management  married   tertiary      no     2143     yes   no
# 1  44.0    technician   single  secondary      no       29     yes   no
# 2  33.0  entrepreneur  married  secondary      no        2     yes  yes
# 3  47.0   blue-collar  married    unknown      no     1506     yes   no
# 4  33.0       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 4      NaN    5   may       198         1     -1         0  unknown      no

# %%
df.count()
# Out:
# age          43872
# job          45211
# marital      45211
# education    45211
# default      43905
# balance      45211
# housing      45211
# loan         45211
# contact      43828
# day          45211
# month        45211
# duration     45211
# campaign     45211
# pdays        45211
# previous     45211
# poutcome     45211
# deposit      45211
# dtype: int64

# %% [markdown]
# Investigate

# %%
df.isna().sum()
# Out:
# age          1339
# job             0
# marital         0
# education       0
# default      1306
# balance         0
# housing         0
# loan            0
# contact      1383
# day             0
# month           0
# duration        0
# campaign        0
# pdays           0
# previous        0
# poutcome        0
# deposit         0
# dtype: int64

# %% [markdown]
# The most comon Na columns are age, default and contact. Let's see how many row left it gets after performing simple data cleaning

# %%
round(df.describe(), 2)
# Out:
#             age    balance       day  duration  campaign     pdays  previous
# count  43872.00   45211.00  45211.00  45211.00  45211.00  45211.00  45211.00
# mean      40.92    1362.27     15.81    258.16      2.76     40.20      0.58
# std       10.61    3044.77      8.32    257.53      3.10    100.13      2.30
# min       18.00   -8019.00      1.00      0.00      1.00     -1.00      0.00
# 25%       33.00      72.00      8.00    103.00      1.00     -1.00      0.00
# 50%       39.00     448.00     16.00    180.00      2.00     -1.00      0.00
# 75%       48.00    1428.00     21.00    319.00      3.00     -1.00      0.00
# max       95.00  102127.00     31.00   4918.00     63.00    871.00    275.00

# %%
df1= df.dropna() # use it for age vs default vs contact

# %%
df1
# Out:
#         age           job   marital  education default  balance housing loan  \
# 0      58.0    management   married   tertiary      no     2143     yes   no
# 1      44.0    technician    single  secondary      no       29     yes   no
# 2      33.0  entrepreneur   married  secondary      no        2     yes  yes
# 3      47.0   blue-collar   married    unknown      no     1506     yes   no
# 5      35.0    management   married   tertiary      no      231     yes   no
# ...     ...           ...       ...        ...     ...      ...     ...  ...
# 45206  51.0    technician   married   tertiary      no      825      no   no
# 45207  71.0       retired  divorced    primary      no     1729      no   no
# 45208  72.0       retired   married  secondary      no     5715      no   no
# 45209  57.0   blue-collar   married  secondary      no      668      no   no
# 45210  37.0  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df1.count()
# Out:
# age          41300
# job          41300
# marital      41300
# education    41300
# default      41300
# balance      41300
# housing      41300
# loan         41300
# contact      41300
# day          41300
# month        41300
# duration     41300
# campaign     41300
# pdays        41300
# previous     41300
# poutcome     41300
# deposit      41300
# dtype: int64

# %% [markdown]
# As it is showen on the table total number of rows 41300. Compare it to avg data loss is below 2,000. So far it is apropriate to clean all Na's

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41300 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        41300 non-null  float64
#  1   job        41300 non-null  object
#  2   marital    41300 non-null  object
#  3   education  41300 non-null  object
#  4   default    41300 non-null  object
#  5   balance    41300 non-null  int64
#  6   housing    41300 non-null  object
#  7   loan       41300 non-null  object
#  8   contact    41300 non-null  object
#  9   day        41300 non-null  int64
#  10  month      41300 non-null  object
#  11  duration   41300 non-null  int64
#  12  campaign   41300 non-null  int64
#  13  pdays      41300 non-null  int64
#  14  previous   41300 non-null  int64
#  15  poutcome   41300 non-null  object
#  16  deposit    41300 non-null  object
# dtypes: float64(1), int64(6), object(10)
# memory usage: 5.7+ MB

# %%
df.dropna(how='all', 
          subset=['age', 'default', 'contact']) # how many missing rows for age & default and contact
# Out:
#         age           job   marital  education default  balance housing loan  \
# 0      58.0    management   married   tertiary      no     2143     yes   no
# 1      44.0    technician    single  secondary      no       29     yes   no
# 2      33.0  entrepreneur   married  secondary      no        2     yes  yes
# 3      47.0   blue-collar   married    unknown      no     1506     yes   no
# 4      33.0       unknown    single    unknown      no        1      no   no
# ...     ...           ...       ...        ...     ...      ...     ...  ...
# 45206  51.0    technician   married   tertiary      no      825      no   no
# 45207  71.0       retired  divorced    primary      no     1729      no   no
# 45208  72.0       retired   married  secondary      no     5715      no   no
# 45209  57.0   blue-collar   married  secondary      no      668      no   no
# 45210  37.0  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# There are 0 rows with Na's for both age, default and contact. The following is true: there are 43872 rows for age and 41300 for df1 (cleaned data) where 43872-41300 stands for 6 % of actual data. Which means that df1 can cause some aditional statistical baise and it must be explored

# %%
df1.skew()
# Out:
# age          0.681967
# balance      8.550459
# day          0.093367
# duration     3.072163
# campaign     4.923013
# pdays        2.618658
# previous    43.296992
# dtype: float64

# %%
round(df1.describe(), 2)
# Out:
#             age    balance       day  duration  campaign     pdays  previous
# count  41300.00   41300.00  41300.00  41300.00  41300.00  41300.00  41300.00
# mean      40.92    1366.56     15.80    258.27      2.76     40.33      0.58
# std       10.60    3074.91      8.32    257.37      3.09    100.35      2.34
# min       18.00   -8019.00      1.00      0.00      1.00     -1.00      0.00
# 25%       33.00      72.00      8.00    103.00      1.00     -1.00      0.00
# 50%       39.00     450.00     16.00    180.00      2.00     -1.00      0.00
# 75%       48.00    1431.00     21.00    319.00      3.00     -1.00      0.00
# max       95.00  102127.00     31.00   3881.00     63.00    871.00    275.00

# %% [markdown]
# There are 7 numerical columns that can be used for statistical values

# %%
describe(df1['age'])
# Out:
# DescribeResult(nobs=41300, minmax=(18.0, 95.0), mean=40.91847457627119, variance=112.32815573980737, skewness=0.6819423920624994, kurtosis=0.3100100925060194)

# %%
sci.normaltest(df1['age']) # perform normal test and find p-value
# Out:
# NormaltestResult(statistic=2776.4324673964015, pvalue=0.0)

# %% [markdown]
# As p-value is 0.0, it became clear that age is withing 100% confidence interval. Which means that df1 is cleaned properlly without any obviuse baises.

# %%
df1.plot.scatter(x='age', y='campaign', title= "age vs campaign")
df1.plot.scatter(x='age', y='duration', title= "age vs duration")
df1.plot.scatter(x='month', y='age', title= "age vs horsepower")
df1.plot.scatter(x='marital', y='age', title= "age vs horsepower")
plt.tight_layout()
plt.show()

# %%
#Regression line with smoothing (error bar) and pairplot
sns.pairplot(df1, kind= "reg")

# %%
sns.pairplot(df1, x_vars=["age", "day"], y_vars=["balance", "duration", "campaign", "pdays"],
             hue="housing", height=5, aspect=.8, kind="reg")

# %%
sns.lmplot(x="age", y="balance", hue="housing", data= df1,
           markers=["o", "x"], palette="Set1")

# %%
sns.lmplot(x="age", y="balance", hue="housing", markers=["o", "x"], col="loan", data=df1)

# %% [markdown]
# Most people who do not have loans have more on their bank accounts and as age goes on balance is incre. At the same time

# %%
#customize plots and show map denisty
g = sns.pairplot(df1, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %%
df.mode()
# Out:
#     age          job  marital  education default  balance housing loan  \
# 0  32.0  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  cellular   20   may       124         1     -1         0  unknown      no

# %% [markdown]
# # Unsupervised ML

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R -i df1
#
# library(ggplot2)
# library(ggpubr)
# library(MLmetrics)
# library(viridis)
# library(tidyverse)
# library(hrbrthemes)
# library(gridExtra)
# library(cluster)
# library(ggplot2)
# library(ggpubr)
# library(MLmetrics)
# library(DBI)
# library(mclust)
# Out:
# R[write to console]:     __  ___________    __  _____________
#    /  |/  / ____/ /   / / / / ___/_  __/
#   / /|_/ / /   / /   / / / /\__ \ / /
#  / /  / / /___/ /___/ /_/ /___/ // /
# /_/  /_/\____/_____/\____//____//_/    version 5.4.8
# Type 'citation("mclust")' for citing this R package in publications.
#
# R[write to console]:
# Attaching package: 'mclust'
#
#
# R[write to console]: The following object is masked from 'package:purrr':
#
#     map

# %%
df1.head()
# Out:
#     age           job  marital  education default  balance housing loan  \
# 0  58.0    management  married   tertiary      no     2143     yes   no
# 1  44.0    technician   single  secondary      no       29     yes   no
# 2  33.0  entrepreneur  married  secondary      no        2     yes  yes
# 3  47.0   blue-collar  married    unknown      no     1506     yes   no
# 5  35.0    management  married   tertiary      no      231     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 5  unknown    5   may       139         1     -1         0  unknown      no

# %%
# %%R -i df1
#
# df2 <- select(df1, -c(job, marital, education, default, housing, loan, contact, month,
#                       previous, poutcome, deposit))

# %%
# %%R -i df1
#
# head(df2)
# Out:
#   age balance day duration campaign pdays
# 0  58    2143   5      261        1    -1
# 1  44      29   5      151        1    -1
# 2  33       2   5       76        1    -1
# 3  47    1506   5       92        1    -1
# 5  35     231   5      139        1    -1
# 6  28     447   5      217        1    -1

# %%
# %%R -i df1
#
# summary(df2)
# Out:
#       age           balance            day          duration
#  Min.   :18.00   Min.   : -8019   Min.   : 1.0   Min.   :   0.0
#  1st Qu.:33.00   1st Qu.:    72   1st Qu.: 8.0   1st Qu.: 103.0
#  Median :39.00   Median :   450   Median :16.0   Median : 180.0
#  Mean   :40.92   Mean   :  1367   Mean   :15.8   Mean   : 258.3
#  3rd Qu.:48.00   3rd Qu.:  1431   3rd Qu.:21.0   3rd Qu.: 319.0
#  Max.   :95.00   Max.   :102127   Max.   :31.0   Max.   :3881.0
#     campaign          pdays
#  Min.   : 1.000   Min.   : -1.00
#  1st Qu.: 1.000   1st Qu.: -1.00
#  Median : 2.000   Median : -1.00
#  Mean   : 2.762   Mean   : 40.33
#  3rd Qu.: 3.000   3rd Qu.: -1.00
#  Max.   :63.000   Max.   :871.00

# %%
# %%R -i df1
# df3 <- df2[df2$age <=80,]
# summary(df3)
# Out:
#       age           balance            day          duration
#  Min.   :18.00   Min.   : -8019   Min.   : 1.0   Min.   :   0.0
#  1st Qu.:33.00   1st Qu.:    72   1st Qu.: 8.0   1st Qu.: 103.0
#  Median :39.00   Median :   450   Median :16.0   Median : 180.0
#  Mean   :40.82   Mean   :  1362   Mean   :15.8   Mean   : 258.1
#  3rd Qu.:48.00   3rd Qu.:  1430   3rd Qu.:21.0   3rd Qu.: 318.0
#  Max.   :80.00   Max.   :102127   Max.   :31.0   Max.   :3881.0
#     campaign          pdays
#  Min.   : 1.000   Min.   : -1.00
#  1st Qu.: 1.000   1st Qu.: -1.00
#  Median : 2.000   Median : -1.00
#  Mean   : 2.764   Mean   : 40.32
#  3rd Qu.: 3.000   3rd Qu.: -1.00
#  Max.   :63.000   Max.   :871.00

# %%
summary(df3)

# %%
# %%R -i df1
# #Convert Glofers to numerical values
# df3$balance <- as.numeric(df3$balance)
# df1 <- scale(df3)
# aclusters <- agnes(df3, method = "complete")
# aclusters
